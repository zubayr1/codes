# %%
q = 11938634925905940014594352962383663996338298043259122520541364488979661578215638739303400859571485638589741791894483933378399034279775304382142982060242139

# %%
p = 11516977743762052942357248250378506537140084812094166990876868646860207651313433835592266786798609581233990601839332241975139490154559828084130856985065047

# %%
z = (p-1)*(q-1)

z
# Out:
# 

# %%
e = 65537

d = 

# %%
(e*d) % z
# Out:
# 

# %%
# Alice wants to send Bob an AES-256 key (b) k. To this end she uses Bob’s public key to encrypt the
# 256-bit key but she forgets to pad the key before encrypting and sending it, i.e., c = RSAEnc(k).
# You intercept the ciphertext and you know that Bob’s public key is e = 3 for RSA-1024. What
# is the key k?
# Hint: Depending on your platform and programming language, you might only be able to
# compute the approximate value! To check your result: The SHA-256 of the first 6 digits is:
# b8786d97c2b37c92daa596ce93cb6970a0c3579a6f392d019f7124d25c97d99a (computed with
# $ echo -n "123456"| sha256sum)

# %%
e = 3

c = 20010346845101449563797069734698074455667514313507070175602069349603820248980338212866767259464828993191274473320041332407706420129745284142443929283464111587899947085015192001416649461837256498629074252755396882572026042071135432

# %%
e = 65537
N = 262708692991318701227987716431222351806486419017027840397139897071949140843716587830322681685295970439228289037529218564171172259919636371
...
# Out:
# ...

# %%
m = 5
s = ...

# %%
for d in range(1, s):
    if s == (m**d)%N:
        print(d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       1 for d in range(1, s):
# ----> 2     if s == (m**d)%N:
#       3         print(d)
#
# KeyboardInterrupt:

# %%
(s**5)%N
# Out:
# 40747869329779948581350703023250742279166364319591888912579563978723010531370761970850241123209183828331750388532775023607967347818934184
